# %% [markdown]
# ## Chapter 1 Data Preparation and Cleaning
#
# This chapter focuses on data transformation and manipulation.

# %% [markdown]
# ### Data Cleaning and Transformation

# %%
# Import the libraries
import pandas as pd

# %%
# Read in sales dataset
sales_df = pd.read_csv('datasets/sales.csv')

# %%
# Inspect the first rows
sales_df.head()
# Out:
#    Year  Product       line Product.1  type  Product.2  Order method  \
# 0  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 1  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 2  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 3  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 4  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
#
#       type.1 Retailer country    Revenue
# 0  Telephone   United  States  315044.33
# 1  Telephone   Canada     NaN   14313.48
# 2  Telephone   Mexico     NaN  156644.47
# 3  Telephone   Brazil     NaN   59191.72
# 4  Telephone    Japan     NaN    7029.33

# %%
# Inspect the last 5 rows
sales_df.tail()
# Out:
#     Year  Product       line Product.1  type  Product.2  Order method type.1  \
# 95  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag   Mail
# 96  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag   Mail
# 97  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag   Mail
# 98  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag   Mail
# 99  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag   Mail
#
#    Retailer  country    Revenue
# 95  Finland      NaN    6615.84
# 96  Denmark      NaN   52613.47
# 97   France      NaN   41912.85
# 98  Germany      NaN   59479.91
# 99   United  Kingdom  156324.28

# %%
# Inspect the dimensions of the DataFrame
sales_df.shape

print(f'This dataset has {sales_df.shape[0]} rows and {sales_df.shape[1]} columns.')
# Out:
# This dataset has 100 rows and 12 columns.

# %%
# Check the data types of the DataFrame
sales_df.dtypes
# Out:
# Year           int64
# Product       object
# line          object
# Product.1     object
# type          object
# Product.2     object
# Order         object
# method        object
# type.1        object
# Retailer      object
# country       object
# Revenue      float64
# dtype: object

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       100 non-null    int64
#  1   Product    100 non-null    object
#  2   line       100 non-null    object
#  3   Product.1  100 non-null    object
#  4   type       100 non-null    object
#  5   Product.2  100 non-null    object
#  6   Order      100 non-null    object
#  7   method     100 non-null    object
#  8   type.1     100 non-null    object
#  9   Retailer   100 non-null    object
#  10  country    9 non-null      object
#  11  Revenue    100 non-null    float64
# dtypes: float64(1), int64(1), object(10)
# memory usage: 9.5+ KB

# %%
# Check for missing values
sales_df.isna().sum()
# Out:
# Year          0
# Product       0
# line          0
# Product.1     0
# type          0
# Product.2     0
# Order         0
# method        0
# type.1        0
# Retailer      0
# country      91
# Revenue       0
# dtype: int64

# %% [markdown]
# The `country` is missing 91 values.

# %%
# Clean the data
# Reorder the columns
cols = ['year', 'product_line', 'product_type','product',
        'retailer_country', 'order_method', 'revenue']

df = (sales_df
      .assign(product_line = sales_df.Product + ' ' + sales_df.line,
              product_type = sales_df['Product.1'] + ' ' + sales_df['type'],
              product = sales_df['Product.2'] + ' ' + sales_df['Order'] + ' ' + sales_df['method'],
              retailer_country = sales_df['Retailer'].replace('United', 'United States')
             )
      .rename(columns = {'type.1':'order_method', 'Revenue':'revenue', 'Year':'year'})
      [cols]  
)

# Inspect the first 5 rows
df.head()
# Out:
#    year       product_line  product_type              product  \
# 0  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 1  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 2  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 3  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 4  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
#
#   retailer_country order_method    revenue
# 0    United States    Telephone  315044.33
# 1           Canada    Telephone   14313.48
# 2           Mexico    Telephone  156644.47
# 3           Brazil    Telephone   59191.72
# 4            Japan    Telephone    7029.33

# %%
df.tail()
# Out:
#     year       product_line  product_type              product  \
# 95  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 96  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 97  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 98  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 99  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
#
#    retailer_country order_method    revenue
# 95          Finland         Mail    6615.84
# 96          Denmark         Mail   52613.47
# 97           France         Mail   41912.85
# 98          Germany         Mail   59479.91
# 99    United States         Mail  156324.28

# %%
df.columns
# Out:
# Index(['year', 'product_line', 'product_type', 'product', 'retailer_country',
#        'order_method', 'revenue'],
#       dtype='object')

# %% [markdown]
# ### Converting the Code into a Function

# %%
def tweak_sales(sales_df):
    """
    Clean and transform sales dataset. 
    i). Use your subject matter expertise to transform the columns as needed.
    """
    
    # Reorder columns
    cols = ['year', 'product_line', 'product_type','product',
        'retailer_country', 'order_method', 'revenue']
    
    # Return a cleaned DataFrame
    return((sales_df
            .assign(product_line = sales_df['Product'] + ' ' + sales_df['line'],
                    product_type = sales_df['Product.1'] + ' ' + sales_df['type'],
                    product = sales_df['Product.2'] + ' ' + sales_df['Order'] + ' ' + sales_df['method'],
                    retailer_country = sales_df['Retailer'].replace('United', 'United States')
                )
            .rename(columns = {'type.1':'order_method', 'Revenue':'revenue', 'Year':'year'})
            [cols]
        )
    )

# %% [markdown]
# Now, let's test our new function

# %%
df = tweak_sales(sales_df)

# Inspect the first 10 rows
df.head(10)
# Out:
#    year       product_line  product_type              product  \
# 0  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 1  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 2  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 3  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 4  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 5  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 6  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 7  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 8  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 9  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
#
#   retailer_country order_method    revenue
# 0    United States    Telephone  315044.33
# 1           Canada    Telephone   14313.48
# 2           Mexico    Telephone  156644.47
# 3           Brazil    Telephone   59191.72
# 4            Japan    Telephone    7029.33
# 5            Korea    Telephone   52613.47
# 6            China    Telephone   41912.85
# 7        Singapore    Telephone   59479.91
# 8        Australia    Telephone  156324.28
# 9      Netherlands    Telephone   23042.67

# %%
# Inspect the last 15 rows
df.tail(15)
# Out:
#     year       product_line  product_type              product  \
# 85  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 86  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 87  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 88  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 89  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 90  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 91  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 92  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 93  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 94  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 95  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 96  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 97  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 98  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 99  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
#
#    retailer_country order_method    revenue
# 85           Canada         Mail    6615.84
# 86           Mexico         Mail   52613.47
# 87           Brazil         Mail   41912.85
# 88            Japan         Mail   59479.91
# 89            Korea         Mail  156324.28
# 90            China         Mail   23042.67
# 91        Singapore         Mail   59479.91
# 92        Australia         Mail   66446.59
# 93      Netherlands         Mail   13620.11
# 94           Sweden         Mail   77447.93
# 95          Finland         Mail    6615.84
# 96          Denmark         Mail   52613.47
# 97           France         Mail   41912.85
# 98          Germany         Mail   59479.91
# 99    United States         Mail  156324.28
